# %%
import pandas as pd

# %%
df = pd.read_csv('pso_resultsMP.csv')
df
# Out:
#         function  swarmsize  dim  maxiter    w   c1   c2  duration  best_iter  \
# 0      quadratic        100    2       60  0.4  1.0  1.0  0.006628         60
# 1      quadratic        100    2       60  0.4  1.0  1.3  0.000646         60
# 2      quadratic        100    2       60  0.4  1.0  1.5  0.000650         60
# 3      quadratic        100    2       60  0.4  1.0  1.7  0.000678         60
# 4      quadratic        100    2       60  0.4  1.0  2.0  0.000422         60
# ...          ...        ...  ...      ...  ...  ...  ...       ...        ...
# 46870     ackley       2000   15     1000  1.0  2.0  1.0  0.359129         32
# 46871     ackley       2000   15     1000  1.0  2.0  1.3  0.366825         48
# 46872     ackley       2000   15     1000  1.0  2.0  1.5  0.364981         86
# 46873     ackley       2000   15     1000  1.0  2.0  1.7  0.409998        117
# 46874     ackley       2000   15     1000  1.0  2.0  2.0  0.381143        240
#
# ...
